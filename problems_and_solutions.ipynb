# %% [markdown]
# Funziona! 503 aziende caricate perfettamente. 🎉
#
# I due problemi erano:
#
# **1. Ambiente sbagliato** — il terminale stava usando `whisper_stepbystep`, un pyenv di un altro tuo progetto, dove `lxml` non era installato. Ora usi il `venv` dedicato (vedi `(.venv)` nel prompt).
#
# **2. Wikipedia bloccava con 403** — Wikipedia rifiuta richieste senza User-Agent, perché le considera bot. Aggiungendo `{"User-Agent": "Mozilla/5.0"}` si fa passare la richiesta come un browser normale.
#
# Prossimo passo: `src/edgar.py` per scaricare i 10-K dalla SEC. Pronta?
